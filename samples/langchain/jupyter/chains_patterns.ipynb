# %% [markdown]
# # LangChain Expression Language (LCEL) with Amazon Nova
#
# This notebook demonstrates chain composition patterns using LangChain Expression Language.
#
# ## Setup

# %%
# %env NOVA_API_KEY=<YOUR-API-KEY>
# %env NOVA_BASE_URL=https://api.nova.amazon.com/v1/

# %%
from langchain_amazon_nova import ChatAmazonNova
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough, RunnableParallel

# Initialize the model
llm = ChatAmazonNova(model="nova-pro-v1", temperature=0.7, streaming=True)

# %% [markdown]
# ## 1. Simple Chain
#
# The most basic LCEL pattern: `prompt | model | parser`

# %%
# Create a simple chain
prompt = ChatPromptTemplate.from_template("Tell me a joke about {topic}")
chain = prompt | llm | StrOutputParser()

# Invoke it
result = chain.invoke({"topic": "programming"})
print(f"Result: {result}")
# Out:
# Result: Sure, here's a classic programming joke:
#
# Why do programmers prefer dark mode?
#
# Because light attracts bugs!

# %% [markdown]
# ## 2. Sequential Chain
#
# Chain multiple operations in sequence.

# %%
# First step: translate
translate_prompt = ChatPromptTemplate.from_template(
    "Translate this to {language}: {text}"
)
translate_chain = translate_prompt | llm | StrOutputParser()

# Second step: summarize
summarize_prompt = ChatPromptTemplate.from_template("Summarize in one sentence: {text}")
summarize_chain = summarize_prompt | llm | StrOutputParser()

# Test translation
translation = translate_chain.invoke(
    {"text": "LangChain is great for building AI applications", "language": "Spanish"}
)
print(f"Translation: {translation}\n")

# Then summarize the translation
summary = summarize_chain.invoke({"text": translation})
print(f"Summary: {summary}")
# Out:
# Translation: Here's your translation:
#
# LangChain es ideal para crear aplicaciones de inteligencia artificial.
#
# If you need any more translations or further assistance with anything else, feel free to ask!
#
# Summary: LangChain is ideal for creating artificial intelligence applications. If you need more translations or further assistance, feel free to ask!

# %% [markdown]
# ## 3. Parallel Execution
#
# Run multiple chains in parallel using `RunnableParallel`.

# %%
# Define two different chains
joke_chain = (
    ChatPromptTemplate.from_template("Tell a joke about {topic}")
    | llm
    | StrOutputParser()
)

poem_chain = (
    ChatPromptTemplate.from_template("Write a haiku about {topic}")
    | llm
    | StrOutputParser()
)

# Run them in parallel
parallel_chain = RunnableParallel(joke=joke_chain, poem=poem_chain)
results = parallel_chain.invoke({"topic": "clouds"})

print("Joke:")
print(results["joke"])
print("\nPoem:")
print(results["poem"])
# Out:
# Joke:
# Sure, here's a light-hearted joke about clouds:
#
# ---
#
# Why did the cloud go to school?
#
# Because it wanted to be a cumulus-nibus!
#
# ---
#
# Hope that brought a smile to your face!
#
# Poem:
# Whispers of sky,
# Clouds dance in silent grace,
# Nature's haiku.

# %% [markdown]
# ## 4. Chain with Branching Logic
#
# Use `RunnablePassthrough` to create more complex data flows.

# %%
# Create a chain that analyzes and then elaborates
analyze_prompt = ChatPromptTemplate.from_template(
    "Analyze this text in 2-3 words: {text}"
)
elaborate_prompt = ChatPromptTemplate.from_template(
    "Original: {original}\nAnalysis: {analysis}\n\nElaborate on the analysis:"
)

# Chain that passes through original text while adding analysis
chain = (
    {
        "original": RunnablePassthrough(),
        "analysis": analyze_prompt | llm | StrOutputParser(),
    }
    | elaborate_prompt
    | llm
    | StrOutputParser()
)

result = chain.invoke("The quick brown fox jumps over the lazy dog")
print(result)
# Out:
# Certainly! Let's break down the sentence "The quick brown fox jumps over the lazy dog" and elaborate on the analysis "Fox jumps."
#
# ### Sentence Breakdown
#
# 1. **Subject**:
#    - **"The quick brown fox"**
#      - **"The"**: Definite article specifying a particular noun.
#      - **"quick"**: Adjective describing the speed of the fox.
#      - **"brown"**: Adjective describing the color of the fox.
#      - **"fox"**: Noun, the main subject of the sentence.
#
# 2. **Verb**:
#    - **"jumps"**: Action verb indicating the movement of the subject.
#
# 3. **Prepositional Phrase**:
#    - **"over the lazy dog"**
#      - **"over"**: Preposition indicating the relationship between the action and the object.
#      - **"the"**: Definite article specifying a particular noun.
#      - **"lazy"**: Adjective describing the state of the dog.
#      - **"dog"**: Noun, the object over which the fox jumps.
#
# ### Elaborated Analysis: "Fox jumps."
#
# 1. **Subject Identification**:
#    - The primary subject of the sentence is "the quick brown fox." When we simplify this to "fox," we retain the core noun performing the action.
#
# 2. **Action Identification**:
#    - The verb "jumps" indicates the action being performed by the subject. This verb is crucial as it conveys the dynamic movement of the fox.
#
# 3. **Object of the Preposition**:
#    - Though the phrase "over the lazy dog" provides additional context about the action, the core idea of the sentence can be distilled to the fox performing the jump.
#
# ### Contextual Significance
#
# - **"The quick brown fox jumps over the lazy dog"** is a pangram—a sentence that uses every letter of the alphabet at least once. It’s often used to test typewriters, keyboards, and fonts.
# - The phrase "fox jumps" captures the essential action and subject, stripping away the descriptive adjectives and the prepositional phrase for a more straightforward interpretation.
#
# ### Summary
#
# - **Core Meaning**: The fundamental action in the sentence is a fox jumping.
# - **Simplified Version**: "Fox jumps" retains the subject and the verb, offering a clear and concise representation of the action taking place.
#
# This analysis helps in understanding the essential components of the sentence while also appreciating the additional descriptive elements that enrich the original pangram.

# %% [markdown]
# ## 5. Chain with Fallbacks
#
# Add fallback behavior for robustness.

# %%
# Primary model
primary = ChatAmazonNova(model="nova-pro-v1", temperature=0.7)

# Fallback model
fallback_model = ChatAmazonNova(model="nova-lite-v1", temperature=0.7)

# Create chain with fallback
prompt = ChatPromptTemplate.from_template("What is {thing}?")
chain_with_fallback = (prompt | primary | StrOutputParser()).with_fallbacks(
    [prompt | fallback_model | StrOutputParser()]
)

result = chain_with_fallback.invoke({"thing": "LangChain"})
print(f"Result: {result}")
# Out:
# Result: LangChain is a framework designed to simplify the creation of applications that use large language models (LLMs). It provides a standard interface for chains, lots of integrations with other tools, and end-to-end chains for common applications. Here’s a breakdown of its key features and components:
#
# ### Key Features:
#
# 1. **Standard Interface**:
#    - LangChain offers a consistent API for interacting with different LLMs, making it easier to switch between models or use multiple models in a single application.
#
# 2. **Chains**:
#    - Chains are sequences of steps where the output of one step is the input to the next. LangChain allows you to create complex workflows by chaining together various components like prompts, LLMs, and tools.
#
# 3. **Agents**:
#    - Agents are more dynamic versions of chains that can make decisions about which tools to use based on the input. They are useful for tasks that require more flexibility and decision-making.
#
# 4. **Memory**:
#    - LangChain provides mechanisms to add memory to chains and agents, allowing them to retain context over multiple interactions. This is useful for maintaining state in conversations or multi-step tasks.
#
# 5. **Integrations**:
#    - The framework includes integrations with various tools and services, such as APIs, databases, and other software, enabling more complex and useful applications.
#
# 6. **Templates and Prompts**:
#    - LangChain offers utilities for managing prompts, including templates that can be filled in with dynamic data. This helps in creating more contextually aware inputs for LLMs.
#
# 7. **Evaluation and Testing**:
#    - Tools for evaluating the performance of chains and agents, helping to iterate and improve your applications.
#
# ### Common Use Cases:
#
# - **Chatbots**: Creating conversational agents that can handle complex queries and maintain context.
# - ** summarization**: Building applications that can summarize long documents or conversations.
# - **Question Answering**: Developing systems that can answer questions based on provided documents or knowledge bases.
# - **Automation**: Creating automated workflows that leverage LLMs for tasks like data extraction, report generation, and more.
#
# ### Example Workflow:
#
# 1. **Define a Prompt**: Create a template for the input to the LLM.
# 2. **Select an LLM**: Choose which language model to use.
# 3. **Chain Components**: Add additional steps like data retrieval, transformation, or additional model calls.
# 4. **Execute the Chain**: Run the chain to get the output.
# 5. **Optional: Add Memory**: Store context to maintain state across interactions.
#
# ### Example Code Snippet:
#
# ```python
# from langchain import PromptTemplate, LLMChain
# from langchain.llms import OpenAI
#
# # Define a prompt template
# prompt = PromptTemplate(
#     input_variables=["product"],
#     template="What is the best {product} to buy in 2023?"
# )
#
# # Initialize the language model
# llm = OpenAI(model_name="text-davinci-003")
#
# # Create a chain
# chain = LLMChain(llm=llm, prompt=prompt)
#
# # Run the chain
# output = chain.run(product="laptop")
# print(output)
# ```
#
# In summary, LangChain is a powerful tool for building applications that leverage the capabilities of large language models, offering a flexible and extensible framework to create complex, context-aware systems.

# %% [markdown]
# ## 6. Streaming Chains
#
# Stream output from chains token by token.

# %%
prompt = ChatPromptTemplate.from_template(
    "Write a short story about {topic} in 3 sentences."
)
chain = prompt | llm | StrOutputParser()

print("Streaming output:")
for chunk in chain.stream({"topic": "a robot learning to paint"}):
    print(chunk, end="", flush=True)
print("\n")
# Out:
# Streaming output:
# In a quiet studio, a robot named Artie, programmed with algorithms of color theory and brush techniques, began to experiment with paints, guided by the delicate touch of an artist's hand. As strokes of vibrant hues graced the canvas, Artie's sensors detected a surge of emotion, a newfound appreciation for the beauty of human expression. With each painting, Artie evolved, blending logic and creativity, until its artwork whispered tales of a machine that had learned to feel through the language of art.

# %% [markdown]
# ## 7. Chain Composition with Data Transformation
#
# Transform data between chain steps.

# %%
# Function to transform data
def extract_keywords(text: str) -> dict:
    words = text.split()
    return {"keywords": ", ".join(words[:3])}


# Chain with transformation
keyword_prompt = ChatPromptTemplate.from_template(
    "Generate a title using these keywords: {keywords}"
)

chain = extract_keywords | keyword_prompt | llm | StrOutputParser()

result = chain.invoke("artificial intelligence machine learning deep neural networks")
print(f"Generated title: {result}")
# Out:
# Generated title: "Harnessing the Power of Artificial Intelligence: Unveiling the Future of Machine Learning"

# %% [markdown]
# ## 8. Advanced Parameters in Chains
#
# Use Phase 1 API parameters for fine-tuned control.

# %%
# Model with advanced parameters
precise_llm = ChatAmazonNova(
    model="nova-pro-v1",
    temperature=0.3,
    max_tokens=100,
    top_p=0.9,
    reasoning_effort="high",
    metadata={"demo": "chains_notebook", "pattern": "advanced_params"},
)

creative_llm = ChatAmazonNova(
    model="nova-pro-v1", temperature=0.9, max_tokens=150, top_p=0.95
)

# Parallel chains with different parameter sets
precise_chain = (
    ChatPromptTemplate.from_template("Calculate: {problem}")
    | precise_llm
    | StrOutputParser()
)

creative_chain = (
    ChatPromptTemplate.from_template("Write a creative analogy for: {concept}")
    | creative_llm
    | StrOutputParser()
)

parallel = RunnableParallel(calculation=precise_chain, analogy=creative_chain)

results = parallel.invoke({"problem": "15% of 240", "concept": "15% of 240"})

print(f"Precise (high reasoning): {results['calculation']}")
print(f"\nCreative (high temperature): {results['analogy']}")
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# File ~/source/nova-langchain/langchain_amazon_nova/samples/langchain/jupyter/.venv/lib/python3.12/site-packages/langchain_amazon_nova/chat_models.py:532, in ChatAmazonNova._generate(self, messages, stop, run_manager, **kwargs)
#     531 try:
# --> 532     response = self.client.chat.completions.create(**params)
#     533 except Exception as e:
#     534     # Map OpenAI SDK errors to Nova exceptions
#
# File ~/source/nova-langchain/langchain_amazon_nova/samples/langchain/jupyter/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/source/nova-langchain/langchain_amazon_nova/samples/langchain/jupyter/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1189, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1188 validate_response_format(response_format)
# -> 1189 return self._post(
#    1190     "/chat/completions",
#    1191     body=maybe_transform(
#    1192         {
#    1193             "messages": messages,
#    1194             "model": model,
#    1195             "audio": audio,
#    1196             "frequency_penalty": frequency_penalty,
#    1197             "function_call": function_call,
#    1198             "functions": functions,
#    1199             "logit_bias": logit_bias,
#    1200             "logprobs": logprobs,
#    1201             "max_completion_tokens": max_completion_tokens,
#    1202             "max_tokens": max_tokens,
#    1203             "metadata": metadata,
#    1204             "modalities": modalities,
#    1205             "n": n,
#    1206             "parallel_tool_calls": parallel_tool_calls,
#    1207             "prediction": prediction,
#    1208             "presence_penalty": presence_penalty,
#    1209             "prompt_cache_key": prompt_cache_key,
#    1210             "prompt_cache_retention": prompt_cache_retention,
#    1211             "reasoning_effort": reasoning_effort,
#    1212             "response_format": response_format,
#    1213             "safety_identifier": safety_identifier,
#    1214             "seed": seed,
#    1215             "service_tier": service_tier,
#    1216             "stop": stop,
#    1217             "store": store,
#    1218             "stream": stream,
#    1219             "stream_options": stream_options,
#    1220             "temperature": temperature,
#    1221             "tool_choice": tool_choice,
#    1222             "tools": tools,
#    1223             "top_logprobs": top_logprobs,
#    1224             "top_p": top_p,
#    1225             "user": user,
#    1226             "verbosity": verbosity,
#    1227             "web_search_options": web_search_options,
#    1228         },
#    1229         completion_create_params.CompletionCreateParamsStreaming
#    1230         if stream
#    1231         else completion_create_params.CompletionCreateParamsNonStreaming,
#    1232     ),
#    1233     options=make_request_options(
#    1234         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1235     ),
#    1236     cast_to=ChatCompletion,
#    1237     stream=stream or False,
#    1238     stream_cls=Stream[ChatCompletionChunk],
#    1239 )
#
# File ~/source/nova-langchain/langchain_amazon_nova/samples/langchain/jupyter/.venv/lib/python3.12/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1256 opts = FinalRequestOptions.construct(
#    1257     method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258 )
# -> 1259 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/source/nova-langchain/langchain_amazon_nova/samples/langchain/jupyter/.venv/lib/python3.12/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1046     log.debug("Re-raising status error")
# -> 1047     raise self._make_status_error_from_response(err.response) from None
#    1049 break
#
# BadRequestError: Error code: 400 - {'message': 'Model nova-pro-v1 does not support reasoning'}
#
# The above exception was the direct cause of the following exception:
#
# NovaValidationError                       Traceback (most recent call last)
# Cell In[11], line 30
#      22 creative_chain = (
#      23     ChatPromptTemplate.from_template("Write a creative analogy for: {concept}")
#      24     | creative_llm
#      25     | StrOutputParser()
#      26 )
#      28 parallel = RunnableParallel(calculation=precise_chain, analogy=creative_chain)
# ---> 30 results = parallel.invoke({"problem": "15% of 240", "concept": "15% of 240"})
#      32 print(f"Precise (high reasoning): {results['calculation']}")
#      33 print(f"\nCreative (high temperature): {results['analogy']}")
#
# File ~/source/nova-langchain/langchain_amazon_nova/samples/langchain/jupyter/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:3854, in RunnableParallel.invoke(self, input, config, **kwargs)
#    3848     with get_executor_for_config(config) as executor:
#    3849         futures = [
#    3850             executor.submit(_invoke_step, step, input, config, key)
#    3851             for key, step in steps.items()
#    3852         ]
#    3853         output = {
# -> 3854             key: future.result()
#    3855             for key, future in zip(steps, futures, strict=False)
#    3856         }
#    3857 # finish the root run
#    3858 except BaseException as e:
#
# File ~/.local/share/uv/python/cpython-3.12.10-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~/.local/share/uv/python/cpython-3.12.10-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/.local/share/uv/python/cpython-3.12.10-macos-aarch64-none/lib/python3.12/concurrent/futures/thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# File ~/source/nova-langchain/langchain_amazon_nova/samples/langchain/jupyter/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:3837, in RunnableParallel.invoke.<locals>._invoke_step(step, input_, config, key)
#    3831 child_config = patch_config(
#    3832     config,
#    3833     # mark each step as a child run
#    3834     callbacks=run_manager.get_child(f"map:key:{key}"),
#    3835 )
#    3836 with set_config_context(child_config) as context:
# -> 3837     return context.run(
#    3838         step.invoke,
#    3839         input_,
#    3840         child_config,
#    3841     )
#
# File ~/source/nova-langchain/langchain_amazon_nova/samples/langchain/jupyter/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:3129, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3127                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3128             else:
# -> 3129                 input_ = context.run(step.invoke, input_, config)
#    3130 # finish the root run
#    3131 except BaseException as e:
#
# File ~/source/nova-langchain/langchain_amazon_nova/samples/langchain/jupyter/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:398, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     384 @override
#     385 def invoke(
#     386     self,
#    (...)    391     **kwargs: Any,
#     392 ) -> AIMessage:
#     393     config = ensure_config(config)
#     394     return cast(
#     395         "AIMessage",
#     396         cast(
#     397             "ChatGeneration",
# --> 398             self.generate_prompt(
#     399                 [self._convert_input(input)],
#     400                 stop=stop,
#     401                 callbacks=config.get("callbacks"),
#     402                 tags=config.get("tags"),
#     403                 metadata=config.get("metadata"),
#     404                 run_name=config.get("run_name"),
#     405                 run_id=config.pop("run_id", None),
#     406                 **kwargs,
#     407             ).generations[0][0],
#     408         ).message,
#     409     )
#
# File ~/source/nova-langchain/langchain_amazon_nova/samples/langchain/jupyter/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1117, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1108 @override
#    1109 def generate_prompt(
#    1110     self,
#    (...)   1114     **kwargs: Any,
#    1115 ) -> LLMResult:
#    1116     prompt_messages = [p.to_messages() for p in prompts]
# -> 1117     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/source/nova-langchain/langchain_amazon_nova/samples/langchain/jupyter/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:927, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     924 for i, m in enumerate(input_messages):
#     925     try:
#     926         results.append(
# --> 927             self._generate_with_cache(
#     928                 m,
#     929                 stop=stop,
#     930                 run_manager=run_managers[i] if run_managers else None,
#     931                 **kwargs,
#     932             )
#     933         )
#     934     except BaseException as e:
#     935         if run_managers:
#
# File ~/source/nova-langchain/langchain_amazon_nova/samples/langchain/jupyter/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1221, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1219     result = generate_from_stream(iter(chunks))
#    1220 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1221     result = self._generate(
#    1222         messages, stop=stop, run_manager=run_manager, **kwargs
#    1223     )
#    1224 else:
#    1225     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/source/nova-langchain/langchain_amazon_nova/samples/langchain/jupyter/.venv/lib/python3.12/site-packages/langchain_amazon_nova/chat_models.py:538, in ChatAmazonNova._generate(self, messages, stop, run_manager, **kwargs)
#     533 except Exception as e:
#     534     # Map OpenAI SDK errors to Nova exceptions
#     535     nova_exception = map_http_error_to_nova_exception(
#     536         e, model_name=self.model_name
#     537     )
# --> 538     raise nova_exception from e
#     540 choice = response.choices[0]
#     541 message_data: Dict[str, Any] = {
#     542     "content": choice.message.content or "",
#     543     "response_metadata": {
#    (...)    546     },
#     547 }
#
# NovaValidationError: Error code: 400 - {'message': 'Model nova-pro-v1 does not support reasoning'}

# %% [markdown]
# ## Summary
#
# **LCEL Chain Patterns:**
#
# | Pattern | Syntax | Use Case |
# |---------|--------|----------|
# | Simple Chain | `prompt \| llm \| parser` | Basic transformations |
# | Sequential | Multiple chains in order | Multi-step processing |
# | Parallel | `RunnableParallel(...)` | Independent concurrent operations |
# | Branching | `RunnablePassthrough()` | Complex data flows |
# | Fallbacks | `.with_fallbacks([...])` | Error handling, redundancy |
# | Streaming | `.stream(...)` | Real-time output |
# | Transformation | Custom functions in chain | Data preprocessing |
#
# **Key Advantages:**
# - **Composable**: Build complex workflows from simple pieces
# - **Readable**: Pipeline syntax makes logic clear
# - **Flexible**: Easy to add/remove/modify steps
# - **Async-ready**: All chains support async execution
# - **Debuggable**: Each step can be tested independently
